# %% [markdown]
# <a href="https://colab.research.google.com/github/baortraam/Machine-learning-projects/blob/master/college_admission_pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Step 1: Import the dependencies**

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, classification_report

# %% [markdown]
# **Step 2: Data preprocessing**

# %% [markdown]
# Upload data

# %%
df = pd.read_csv('/content/genz_college_admission_prediction.csv', encoding = 'latin-1')
df
# Out:
#         student_id  age  gender       state  family_income  high_school_gpa  \
# 0                1   22    Male        Ohio          32560             3.20
# 1                2   19    Male    Virginia          39084             4.00
# 2                3   20    Male        Ohio          21615             2.90
# 3                4   22    Male    Illinois         109493             3.86
# 4                5   18    Male     Florida          50314             2.50
# ...            ...  ...     ...         ...            ...              ...
# 999995      999996   20  Female    New York         127978             3.98
# 999996      999997   16    Male        Ohio          47661             3.49
# 999997      999998   21  Female  Washington          88044             2.77
# 999998      999999   17  Female    Virginia          55654             3.71
# 999999     1000000   18    Male  California          59923             3.41
#
# ...

# %%
df.describe()
# Out:
#            student_id             age   family_income  high_school_gpa  \
# count  1000000.000000  1000000.000000  1000000.000000   1000000.000000
# mean    500000.500000       19.000294    71701.069023         3.188329
# std     288675.278933        1.999321    47253.555181         0.476299
# min          1.000000       16.000000     2124.000000         0.870000
# 25%     250000.750000       17.000000    39953.000000         2.860000
# 50%     500000.500000       19.000000    59877.000000         3.200000
# 75%     750000.250000       21.000000    89688.000000         3.540000
# max    1000000.000000       22.000000   977775.000000         4.000000
#
#             sat_score       act_score  attendance_rate      ap_courses  \
# count  1000000.000000  1000000.000000   1000000.000000  1000000.000000
# mean      1099.198467       23.468139        91.748151        2.999739
# std        217.409113        5.908590         5.526156        1.729285
# ...

# %% [markdown]
# Drop irrelevant features

# %%
df =  df.drop(columns = ['student_id', 'age',	'gender',	'state'])
df
# Out:
#         family_income  high_school_gpa  sat_score  act_score  attendance_rate  \
# 0               32560             3.20        734         27             91.0
# 1               39084             4.00        988         26            100.0
# 2               21615             2.90       1600         28             97.7
# 3              109493             3.86       1302         28             91.6
# 4               50314             2.50       1342         30             91.8
# ...               ...              ...        ...        ...              ...
# 999995         127978             3.98        984         27             94.9
# 999996          47661             3.49        940         25             80.6
# 999997          88044             2.77       1103         16             95.9
# 999998          55654             3.71       1208         27             87.8
# 999999          59923             3.41       1241         28             94.0
#
# ...

# %% [markdown]
# Split data into X, y

# %%
X = df.iloc[:, 0:15]

# %%
y = df.iloc[:, 15]

# %% [markdown]
# Scale X

# %%
scaler = StandardScaler()

# %%
X = scaler.fit_transform(X)
X
# Out:
# array([[-0.8283205 ,  0.02450365, -1.67977618, ...,  1.81171525,
#          1.27058644, -0.07403104],
#        [-0.69025675,  1.70412308, -0.5114713 , ..., -1.27165842,
#         -2.3045449 ,  1.39262494],
#        [-1.0599434 , -0.60535363,  2.3034995 , ...,  0.02437502,
#         -0.77523943, -0.1910881 ],
#        ...,
#        [ 0.34585629, -0.87829179,  0.01748563, ..., -0.15351193,
#          0.8047053 ,  0.33222578],
#        [-0.33959513,  1.09526104,  0.50044631, ..., -0.19586596,
#         -1.72725741, -0.12223101],
#        [-0.24925267,  0.46540375,  0.65223395, ..., -0.39069452,
#          1.39212065, -1.2032873 ]])

# %% [markdown]
# Splitting the dataset into training and testing sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 11,
                                                          test_size = 0.2,
                                                          stratify = y)

# %% [markdown]
# **Step 3: Training model**

# %%
model = LogisticRegression(class_weight = 'balanced',
                           random_state = 42)

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.785825

# %%
model.score(X_train, y_train)
# Out:
# 0.78824

# %% [markdown]
# **Step 4: Model evaluation**

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[ 19153   4589]
#  [ 38246 138012]]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.33      0.81      0.47     23742
#            1       0.97      0.78      0.87    176258
#
#     accuracy                           0.79    200000
#    macro avg       0.65      0.79      0.67    200000
# weighted avg       0.89      0.79      0.82    200000

# %% [markdown]
# **Step 5: Make a predictive system**

# %%
input_data = ()

input_data_to_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_to_numpy_array.reshape(1,-1)

y_predict = model.predict(input_data_reshaped)

if (y_predict[0]=='1'):
  print('Accepted')
else:
  print('Rejected')

# %% [markdown]
# Example:

# %%
input_data = (109493,3.86,1302,28,91.6,4,3,98,0,2,1.8,2,80.7,81.9,98.7)

input_data_to_numpy_array = np.asarray(input_data)

input_data_reshaped = input_data_to_numpy_array.reshape(1,-1)

y_predict = model.predict(input_data_reshaped)

if (y_predict[0]=='1'):
  print('Accepted')
else:
  print('Rejected')
# Out:
# Rejected
